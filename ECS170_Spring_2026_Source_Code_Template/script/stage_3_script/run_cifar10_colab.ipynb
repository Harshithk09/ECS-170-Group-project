# %% [markdown]
# # Stage 3 CIFAR-10 Training
#
# Run this notebook in Google Colab with **Runtime > Change runtime type > T4 GPU**. It clones the latest project code, installs dependencies, and runs the Stage 3 CIFAR-10 script.

# %%
import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %%
# !git clone https://github.com/Harshithk09/ECS-170-Group-project.git
# %cd ECS-170-Group-project
# !git checkout master
# !git pull --ff-only

# %%
# !pip -q install scikit-learn matplotlib pandas

# %% [markdown]
# The next cell runs the full CIFAR-10 training job. The current code uses WideResNet-28-10, 300 epochs, MixUp, Cutout, label smoothing, and cosine learning-rate decay. This can take a while even on a GPU.

# %%
# %cd /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/script/stage_3_script
# !python script_cifar10_cnn.py

# %%
from pathlib import Path
result_dir = Path('/content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/result/stage_3_result')
print('Result files:')
for path in sorted(result_dir.glob('*cifar*')) + sorted(result_dir.glob('*CIFAR*')):
    print(path, path.stat().st_size, 'bytes')
    if path.suffix.lower() == '.txt':
        print(path.read_text()[:2000])

# %%
from google.colab import files
result_dir = Path('/content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/result/stage_3_result')
for filename in ['CIFAR10_CNN_metrics.txt', 'cifar10_convergence_curve.png']:
    path = result_dir / filename
    if path.exists():
        files.download(str(path))
