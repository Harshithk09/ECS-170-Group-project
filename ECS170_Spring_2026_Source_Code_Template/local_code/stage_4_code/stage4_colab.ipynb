# %% [markdown]
# # Stage 4: RNN Text Classification & Generation

# %%
# ── Step 1: Check GPU ─────────────────────────────────────
import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
# ── Step 2: Mount Google Drive ────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ── Step 3: Clone repo and pull latest code ───────────────
# !git clone https://github.com/Harshithk09/ECS-170-Group-project.git
# %cd ECS-170-Group-project
# !git checkout main
# !git pull origin main
# Out:
# Cloning into 'ECS-170-Group-project'...
# remote: Enumerating objects: 414, done.
# remote: Counting objects: 100% (414/414), done.
# remote: Compressing objects: 100% (216/216), done.
# remote: Total 414 (delta 201), reused 400 (delta 187), pack-reused 0 (from 0)
# Receiving objects: 100% (414/414), 3.63 MiB | 8.75 MiB/s, done.
# Resolving deltas: 100% (201/201), done.
# /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/ECS-170-Group-project
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# From https://github.com/Harshithk09/ECS-170-Group-project
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# ── Step 4: Link dataset from Drive into repo ─────────────
# Make sure your stage_4_data folder is uploaded to:
#   My Drive/ECS170/stage_4_data/
# before running this cell.
import os
from pathlib import Path

data_dest = Path('/content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/data/stage_4_data')
data_src  = Path('/content/drive/MyDrive/ECS170/stage_4_data')

if not data_dest.exists():
    os.symlink(str(data_src), str(data_dest))
    print('Symlink created:', data_dest, '->', data_src)
else:
    print('Data folder already linked:', data_dest)

# Verify the data is visible
print('\nContents of stage_4_data:')
for p in sorted(data_dest.iterdir()):
    print(' ', p.name)
# Out:
# Data folder already linked: /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/data/stage_4_data
#
# Contents of stage_4_data:
#   .DS_Store
#   text_classification
#   text_generation

# %%
# ── Step 5: Install any missing dependencies ──────────────
# !pip install -q scikit-learn matplotlib

# %%
# ── Step 6: Run Generation (faster, run this first) ───────
# %cd /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template
# !python script/stage_4_script/Script_RNN_Generation.py
# Out:
# /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template
# ************ Stage 4: RNN Text Generation ************
# Start words: ['what', 'did', 'the']
# Reading jokes from: /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/data/stage_4_data/text_generation/data
#   Jokes loaded: 1,623
#   Total tokens in corpus: 23,912
#   Vocabulary size: 8,000 tokens
#   Training samples (sliding windows): 23,892
# Dataset ready.
#
# ...
#   Cell type: RNN
# ...
# Using device: cuda
# Using device: cuda
# method running...
# --start training...
# Epoch: 1  Loss: 5.8890  Perplexity: 361.06
# Epoch: 3  Loss: 2.2469  Perplexity: 9.46
# Epoch: 5  Loss: 1.6591  Perplexity: 5.25
# Epoch: 7  Loss: 1.4028  Perplexity: 4.07
# Epoch: 9  Loss: 1.2538  Perplexity: 3.50
# Epoch: 11  Loss: 1.1506  Perplexity: 3.16
# Epoch: 13  Loss: 1.0810  Perplexity: 2.95
# Epoch: 15  Loss: 1.0292  Perplexity: 2.80
# Epoch: 17  Loss: 0.9875  Perplexity: 2.68
# Epoch: 19  Loss: 0.9540  Perplexity: 2.60
# ...

# %%
# ── Step 7: Run Classification (larger dataset, ~20 min) ──
# %cd /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template
# !python script/stage_4_script/Script_RNN_Classification.py
# Out:
# /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template
# ************ Stage 4: RNN Text Classification ************
#
# ...
#   Cell type: RNN
# ...
# Reading train/pos ...
# Reading train/neg ...
# Reading test/pos ...
# Reading test/neg ...
#   Train samples : 25,000  (pos=12,500  neg=12,500)
#   Test  samples : 25,000  (pos=12,500  neg=12,500)
# Cleaning and tokenizing ...
# Building vocabulary ...
#   Vocabulary size : 20,000 tokens
# Dataset ready.
# Using device: cuda
# Using device: cuda
# --start training...
# method running...
# --start training...
# Epoch: 1  Loss: 0.6892  Accuracy: 0.5527
# Epoch: 3  Loss: 0.6280  Accuracy: 0.6640
# Epoch: 5  Loss: 0.5784  Accuracy: 0.7134
# Epoch: 7  Loss: 0.5191  Accuracy: 0.7600
# Epoch: 9  Loss: 0.4593  Accuracy: 0.7964
# Convergence plot saved to: /content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/result/stage_4_result/RNN_classification_convergence_rnn.png
# --start testing...
#
# ---- RNN Results ----
# ...

# %%
# ── Step 8: Check result files ────────────────────────────
from pathlib import Path

result_dir = Path('/content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/result/stage_4_result')
print('Files saved to result/stage_4_result:')
for f in sorted(result_dir.glob('*')):
    print(f'  {f.name}  ({f.stat().st_size:,} bytes)')

# Print contents of each metrics/output text file
for f in sorted(result_dir.glob('*.txt')):
    print(f'\n──── {f.name} ────')
    print(f.read_text())
# Out:
# Files saved to result/stage_4_result:
#   RNN_classification_convergence_gru.png  (77,014 bytes)
#   RNN_classification_convergence_lstm.png  (78,011 bytes)
#   RNN_classification_convergence_rnn.png  (80,451 bytes)
#   RNN_classification_metrics_gru.txt  (291 bytes)
#   RNN_classification_metrics_lstm.txt  (292 bytes)
#   RNN_classification_metrics_rnn.txt  (291 bytes)
#   RNN_generation_convergence_gru.png  (62,780 bytes)
#   RNN_generation_convergence_lstm.png  (65,702 bytes)
#   RNN_generation_convergence_rnn.png  (61,985 bytes)
#   RNN_generation_output_gru.txt  (516 bytes)
#   RNN_generation_output_lstm.txt  (505 bytes)
#   RNN_generation_output_rnn.txt  (491 bytes)
#
# ──── RNN_classification_metrics_gru.txt ────
# Cell type : GRU
# Epochs    : 10
# Vocab size: 20000
#
# ---- Evaluation Metrics ----
# accuracy: 0.8676
# f1_weighted: 0.8676
# precision_weighted: 0.8683
# recall_weighted: 0.8676
# f1_macro: 0.8676
# precision_macro: 0.8683
# recall_macro: 0.8676
# ...

# %%
# ── Step 9: Download all results ──────────────────────────
from google.colab import files
from pathlib import Path

result_dir = Path('/content/ECS-170-Group-project/ECS170_Spring_2026_Source_Code_Template/result/stage_4_result')
for f in sorted(result_dir.glob('*')):
    print('Downloading:', f.name)
    files.download(str(f))
# Out:
# Downloading: RNN_classification_convergence_gru.png
# Downloading: RNN_classification_convergence_lstm.png
# Downloading: RNN_classification_convergence_rnn.png
# Downloading: RNN_classification_metrics_gru.txt
# Downloading: RNN_classification_metrics_lstm.txt
# Downloading: RNN_classification_metrics_rnn.txt
# Downloading: RNN_generation_convergence_gru.png
# Downloading: RNN_generation_convergence_lstm.png
# Downloading: RNN_generation_convergence_rnn.png
# Downloading: RNN_generation_output_gru.txt
# Downloading: RNN_generation_output_lstm.txt
# Downloading: RNN_generation_output_rnn.txt
